# %%
import os
if os.path.basename(os.getcwd()) == 'notebooks':
 os.chdir('../')
print(f"Current working directory: {os.getcwd()}")
from logic.hybrid_score import hybrid_risk_score  # Import the hybrid scoring function
print("--- Starting Hybrid Score Tests ---")
print()
#  Test Case 1: High debt, negative cash flow
result1 = hybrid_risk_score(3.5, -8000)
print("Test Case 1:")
print(result1)
print()

#  Test Case 2: Low debt, strong cash flow
result2 = hybrid_risk_score(1.2, 15000)
print("Test Case 2:")
print(result2)
print()

#  Test Case 3: Moderate debt, borderline cash flow
result3 = hybrid_risk_score(2.1, 5000)
print("Test Case 3:")
print(result3)
print()

#  Test Case 4: Model vs Rule conflict
result4 = hybrid_risk_score(2.5, -1000)
print("Test Case 4:")
print(result4)
print()
# Out:
# Current working directory: C:\Users\nooka\Desktop\risk_assessment_tool
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       3  os.chdir('../')
#       4 print(f"Current working directory: {os.getcwd()}")
# ----> 5 from logic.hybrid_score import hybrid_risk_score  # Import the hybrid scoring function
#       6 print("--- Starting Hybrid Score Tests ---")
#       7 print()
#
# File ~\Desktop\risk_assessment_tool\logic\hybrid_score.py:5
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
# ----> 5    "execution_count": null,
#       6    "id": "9f92f9f1-c730-416c-b02c-4065803bd008",
#       7    "metadata": {},
#       8    "outputs": [],
#       9    "source": [
#      10     "# Why This Matters\n",
#      11     "\n",
#      12     "# Combines data-driven prediction with human logic\n",
#      13     "\n",
#      14     "# Flags conflicts between model and rules\n",
#      15     "\n",
#      16     "# Gives a final decision with full transparency"
#      17    ]
#      18   },
#      19   {
#      20    "cell_type": "code",
#      21    "execution_count": 3,
#      22    "id": "e12c4af9-dbbd-4bcb-b570-41b28d34c266",
#      23    "metadata": {
#      24     "scrolled": true
#      25    },
#      26    "outputs": [
#      27     {
#      28      "ename": "ModuleNotFoundError",
#      29      "evalue": "No module named 'rules'",
#      30      "output_type": "error",
#      31      "traceback": [
#      32       "\u001b---------------------------------------------------------------------------\u001b",
#      33       "\u001bModuleNotFoundError\u001b                       Traceback (most recent call last)",
#      34       "\u001bCell\u001b\u001b \u001b\u001bIn[3]\u001b\u001b, line 5\u001b\n\u001b      3\u001b \u001bimport\u001b\u001b \u001b\u001bjoblib\u001b\n\u001b      4\u001b \u001bimport\u001b\u001b \u001b\u001bnumpy\u001b\u001b \u001b\u001bas\u001b\u001b \u001b\u001bnp\u001b\n\u001b----> \u001b\u001b5\u001b \u001bfrom\u001b\u001b \u001b\u001brules\u001b\u001b \u001b\u001bimport\u001b apply_rules\n\u001b      7\u001b \u001b# Load the trained model\u001b\n\u001b      8\u001b model = joblib.load(\u001b'\u001b\u001b../models/logistic_model.pkl\u001b\u001b'\u001b)\n",
#      35       "\u001bModuleNotFoundError\u001b: No module named 'rules'"
#      36      ]
#      37     }
#      38    ],
#      39    "source": [
#      40     "import joblib\n",
#      41     "import numpy as np\n",
#      42     "from .rules import apply_rules\n",
#      43     "\n",
#      44     "# Load the trained model\n",
#      45     "model = joblib.load('models/logistic_model.pkl')\n",
#      46     "\n",
#      47     "def hybrid_risk_score(debt_to_equity, cash_flow):\n",
#      48     "    # Model prediction\n",
#      49     "    input_data = np.array([[debt_to_equity, cash_flow]])\n",
#      50     "    model_pred = model.predict(input_data)[0]\n",
#      51     "    model_conf = model.predict_proba(input_data)[0][model_pred]\n",
#      52     "    model_label = \"High Risk\" if model_pred == 1 else \"Low Risk\"\n",
#      53     "\n",
#      54     "    # Rule-based override\n",
#      55     "    rule_label = apply_rules(debt_to_equity, cash_flow)\n",
#      56     "\n",
#      57     "    # Combine logic\n",
#      58     "    if \"High Risk\" in rule_label and model_label == \"Low Risk\":\n",
#      59     "        final_label = \"High Risk (Rule override)\"\n",
#      60     "    elif \"Low Risk\" in rule_label and model_label == \"High Risk\":\n",
#      61     "        final_label = \"Medium Risk (Model vs Rule conflict)\"\n",
#      62     "    else:\n",
#      63     "        final_label = model_label\n",
#      64     "\n",
#      65     "    return {\n",
#      66     "        \"model\": model_label,\n",
#      67     "        \"confidence\": round(model_conf, 2),\n",
#      68     "        \"rule\": rule_label,\n",
#      69     "        \"final\": final_label\n",
#      70     "    }\n"
#      71    ]
#      72   },
#      73   {
#      74    "cell_type": "code",
#      75    "execution_count": null,
#      76    "id": "dba227d1-40aa-4d62-b9f0-31572a2200b1",
#      77    "metadata": {},
#      78    "outputs": [],
#      79    "source": []
#      80   }
#      81  ],
#      82  "metadata": {
#      83   "kernelspec": {
#      84    "display_name": "Python 3 (ipykernel)",
#      85    "language": "python",
#      86    "name": "python3"
#      87   },
#      88   "language_info": {
#      89    "codemirror_mode": {
#      90     "name": "ipython",
#      91     "version": 3
#      92    },
#      93    "file_extension": ".py",
#      94    "mimetype": "text/x-python",
#      95    "name": "python",
#      96    "nbconvert_exporter": "python",
#      97    "pygments_lexer": "ipython3",
#      98    "version": "3.13.7"
#      99   }
#     100  },
#     101  "nbformat": 4,
#     102  "nbformat_minor": 5
#     103 }
#
# NameError: name 'null' is not defined
